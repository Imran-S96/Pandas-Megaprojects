# %%
import pandas as pd

df = pd.read_csv("netflix_titles.csv")

# %%
# Filter for only Movies from the United States 
df = df[df['country'] == 'United States']
df = df[df['type'] == 'Movie']

# %%
df['date_added'] = pd.to_datetime(df['date_added'])

# Format the date column as 'dd-mm-yyyy'
df['date_added'] = df['date_added'].dt.strftime('%Y-%m-%d')

# %%
# Replace Values 
df['duration'] = df['duration'].str.replace('min', '')

# %%
# Split listed_in and explode them
df['listed_in'] = df['listed_in'].str.split(',')
df = df.explode('listed_in')
df.reset_index(drop=True, inplace=True)

# Split cast and explode them
df['cast'] = df['cast'].str.split(',')
df = df.explode('cast')
df.reset_index(drop=True, inplace=True)

# %%
# Rename Columns
df.rename(columns={'duration': 'duration(m)'}, inplace=True)
df.rename(columns={'listed_in': 'genre'}, inplace=True)

# %%
df
# Out:
#       show_id   type title      director                  cast        country  \
# 0          s4  Movie     9   Shane Acker           Elijah Wood  United States
# 1          s4  Movie     9   Shane Acker        John C. Reilly  United States
# 2          s4  Movie     9   Shane Acker     Jennifer Connelly  United States
# 3          s4  Movie     9   Shane Acker   Christopher Plummer  United States
# 4          s4  Movie     9   Shane Acker        Crispin Glover  United States
# ...       ...    ...   ...           ...                   ...            ...
# 25015   s7782  Movie  Zoom  Peter Hewitt           Ryan Newman  United States
# 25016   s7782  Movie  Zoom  Peter Hewitt       Michael Cassidy  United States
# 25017   s7782  Movie  Zoom  Peter Hewitt       Spencer Breslin  United States
# 25018   s7782  Movie  Zoom  Peter Hewitt              Rip Torn  United States
# 25019   s7782  Movie  Zoom  Peter Hewitt          Kevin Zegers  United States
#
#        date_added  release_year rating duration           listed_in  \
# 0      2017-11-16          2009  PG-13      80   Action & Adventure
# 1      2017-11-16          2009  PG-13      80   Action & Adventure
# 2      2017-11-16          2009  PG-13      80   Action & Adventure
# 3      2017-11-16          2009  PG-13      80   Action & Adventure
# 4      2017-11-16          2009  PG-13      80   Action & Adventure
# ...           ...           ...    ...      ...                 ...
# 25015  2020-01-11          2006     PG      88             Comedies
# 25016  2020-01-11          2006     PG      88             Comedies
# 25017  2020-01-11          2006     PG      88             Comedies
# 25018  2020-01-11          2006     PG      88             Comedies
# 25019  2020-01-11          2006     PG      88             Comedies
#
#                                              description
# 0      In a postapocalyptic world, rag-doll robots hi...
# 1      In a postapocalyptic world, rag-doll robots hi...
# 2      In a postapocalyptic world, rag-doll robots hi...
# 3      In a postapocalyptic world, rag-doll robots hi...
# 4      In a postapocalyptic world, rag-doll robots hi...
# ...                                                  ...
# 25015  Dragged from civilian life, a former superhero...
# 25016  Dragged from civilian life, a former superhero...
# 25017  Dragged from civilian life, a former superhero...
# 25018  Dragged from civilian life, a former superhero...
# 25019  Dragged from civilian life, a former superhero...
#
# [25020 rows x 12 columns]
